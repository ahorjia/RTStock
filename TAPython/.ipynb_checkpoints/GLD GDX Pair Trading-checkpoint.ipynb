# 2007-10-25  43.936668  173400
# 2007-10-26  44.546669  149400
# 2007-10-29  44.886669  159000
# 2007-10-30  43.630001  229200
# 2007-10-31  44.773331  302400
# 2007-11-01  43.776669  280200
# 2007-11-02  44.533329  219900
# 2007-11-05  44.166672  141300
# 2007-11-06  45.360001  180300
# 2007-11-07  44.166672  276600
# 2007-11-08  44.453331  316800
# 2007-11-09  43.673328  162000
# 2007-11-12  41.626671  295800
# 2007-11-13  42.433331  219900
# 2007-11-14  42.546669  107700
#
# [1504 rows x 7 columns]

# %%
def annualised_sharpe(returns, N=252):
    return np.sqrt(N) * returns.mean() / returns.std()

# %%
def long_only_sharpe(col, risk_free_rate=0.04):
    dr_col = col.pct_change()
    edr_col= dr_col - risk_free_rate / 252.0
    return annualised_sharpe(edr_col)

# %%
print long_only_sharpe(ige['Adj Close'])
print long_only_sharpe(spy['Adj Close'])
# Out:
# 0.72829824241
# 0.0835946977652

# %%
def market_neutral_sharpe(tick, benchmark):
    col1 = tick['Close'].pct_change()
    col2 = benchmark['Close'].pct_change()

    diff_pd = pd.DataFrame(index=tick.index)
    diff_pd['net_ret'] = (col1 - col2)/2.0

    return annualised_sharpe(diff_pd['net_ret'])

def net_ret(tick):
    return tick.pct_change()

# %%
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2013, 5, 29)
gs  = data.DataReader('GS', 'google', start, end)
spy = data.DataReader('SPY', 'google', start, end)
gog = data.DataReader('GOOG', 'google', start, end)

# %%
spy.tail()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2013-05-22  167.34  169.07  165.17  165.93  244031724
# 2013-05-23  164.16  165.91  163.94  165.45  211064320
# 2013-05-24  164.47  165.38  163.98  165.31  151573867
# 2013-05-28  167.04  167.78  165.81  166.30  143679738
# 2013-05-29  165.42  165.80  164.34  165.22  160363334

# %%
gog.tail()
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2013-05-22  450.83  454.20  443.00  444.27     NaN
# 2013-05-23  438.06  444.54  436.56  440.95     NaN
# 2013-05-24  437.19  438.97  435.07  436.22     NaN
# 2013-05-28  441.31  445.62  439.76  440.19     NaN
# 2013-05-29  437.42  438.56  431.71  433.72     NaN

# %%
print market_neutral_sharpe(gs, spy)
print market_neutral_sharpe(goog, spy)
# Out:
# 0.326942032212
# 0.827995497688

# %%
print long_only_sharpe(gs['Close'])
print long_only_sharpe(goog['Close'])
# Out:
# 0.219902203374
# 0.774217754599

# %%
cumret = np.cumprod(1 + net_ret(ige['Adj Close'])) - 1
cumret.plot()

# %%
def measure_drawdowns(daily_returns):

    cumret = np.cumprod(1 + daily_returns) - 1
    
    hwm = [0] # High Watermark
    eq_idx = cumret.index
    drawdown = pd.Series(index = eq_idx)
    duration = pd.Series(index = eq_idx)

    # Loop over the index range
    for t in range(1, len(eq_idx)):
        hwm.append(max(hwm[t-1], cumret[t]))
        drawdown[t]= (1 + hwm[t]) / (1 + cumret[t]) - 1
        if drawdown[t] <= 0:
            duration[t]= 0
        else:
            duration[t] = duration[t-1] + 1
    plt.plot(drawdown)
    return drawdown.max(), duration.max()

# %%
measure_drawdowns(net_ret(ige['Adj Close']))
# Out:
# (0.46689019279128208, 437.0)
