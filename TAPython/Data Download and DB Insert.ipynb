# %%
from __future__ import print_function
import datetime
import warnings
from math import ceil
import bs4
import MySQLdb as mdb
import requests
from pandas_datareader import data, wb
import urllib
import pandas as pd

# %%
def get_list_sp500():

    now = datetime.datetime.utcnow()
    
    response = requests.get(
        "http://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    )

    soup = bs4.BeautifulSoup(response.text)
    symbolslist = soup.select("table")[0].select("tr")[1:]
    symbols = []
    for i, symbol in enumerate(symbolslist):
        tds = symbol.select("td")
        symbols.append(
        (
            tds[0].select("a")[0].text,
            "stock",
            tds[1].select("a")[0].text,
            tds[3].text,
            "USD",
            now,
            now
        ))
    return symbols

# %%
def insert_db(symbols, conn):

    column_str = """ticker, instrument, name, sector,
    currency, created_date, last_updated_date
    """
    
    insert_str = ("%s, " * 7)[:-2]
    final_str = "INSERT INTO symbol (%s) VALUES (%s)" % \
        (column_str, insert_str)

    cur = conn.cursor()
    cur.executemany(final_str, symbols)

# %%
def get_tickers(conn):
    cur = con.cursor()
    cur.execute("SELECT id, ticker FROM symbol")
    data = cur.fetchall()
    return [(d[0], d[1]) for d in data]

# %%
def get_daily_data(ticker):
    
    try:
        yf_data = data.DataReader(ticker, 'yahoo')
        prices = []
        for index, y in yf_data.iterrows():
            prices.append(
                (index,
                y['Open'], y['High'], y['Low'], y['Close'], y['Adj Close'], y['Volume'])
            )
        return prices
    except Exception as e:
        print("Could not download Yahoo data: %s" % e)
    return []

# %%
def insert_daily_data_into_db(
        data_vendor_id, symbol_id, daily_data, conn
    ):

    now = datetime.datetime.utcnow()

    daily_data = [
        (data_vendor_id, symbol_id, d[0], now, now,
        d[1], d[2], d[3], d[4], d[5], d[6])
        for d in daily_data
    ]

    column_str = """data_vendor_id, symbol_id, price_date, created_date,
    last_updated_date, open_price, high_price, low_price,
    close_price, volume, adj_close_price"""
    
    insert_str = ("%s, " * 11)[:-2]
    final_str = "INSERT INTO daily_price (%s) VALUES (%s)" % \
        (column_str, insert_str)

    cur = conn.cursor()
    cur.executemany(final_str, daily_data)

# %%
db_host = "localhost"
db_user = "sec_user"
db_pass = "kiano045"
db_name = "securities_master"

con = mdb.connect(
    host=db_host, user=db_user, passwd=db_pass, db=db_name
)

warnings.filterwarnings('ignore')

with con:
    symbols = get_list_sp500()
    insert_db(symbols, con)
    symbols = get_tickers(con)
    lentickers = len(symbols)
    for i, t in enumerate(symbols):
        print(
            "Adding data for %s: %s out of %s" %
            (t[1], i+1, lentickers)
        )
        
        sym = t[1].replace('.', '%2E')
        try:
            yf_data = get_daily_data(sym)
            insert_daily_data_into_db('1', t[0], yf_data, con)
        except Exception as e:
            print("Error processing %s" % t[1])

    print("Successfully added data.")
# Out:
# Adding data for MMM: 1 out of 505
# Adding data for ABT: 2 out of 505
# Adding data for ABBV: 3 out of 505
# Adding data for ACN: 4 out of 505
# Adding data for ATVI: 5 out of 505
# Adding data for AYI: 6 out of 505
# Adding data for ADBE: 7 out of 505
# Adding data for AMD: 8 out of 505
# Adding data for AAP: 9 out of 505
# Adding data for AES: 10 out of 505
# Adding data for AET: 11 out of 505
# Adding data for AMG: 12 out of 505
# Adding data for AFL: 13 out of 505
# Adding data for A: 14 out of 505
# Adding data for APD: 15 out of 505
# Adding data for AKAM: 16 out of 505
# Adding data for ALK: 17 out of 505
# Adding data for ALB: 18 out of 505
# Adding data for ARE: 19 out of 505
# Adding data for ALXN: 20 out of 505
# Adding data for ALGN: 21 out of 505
# Adding data for ALLE: 22 out of 505
# Adding data for AGN: 23 out of 505
# Adding data for ADS: 24 out of 505
# Adding data for LNT: 25 out of 505
# Adding data for ALL: 26 out of 505
# Adding data for GOOGL: 27 out of 505
# Adding data for GOOG: 28 out of 505
# Adding data for MO: 29 out of 505
# Adding data for AMZN: 30 out of 505
# Adding data for AEE: 31 out of 505
# Adding data for AAL: 32 out of 505
# Adding data for AEP: 33 out of 505
# Adding data for AXP: 34 out of 505
# Adding data for AIG: 35 out of 505
# Adding data for AMT: 36 out of 505
# Adding data for AWK: 37 out of 505
# Adding data for AMP: 38 out of 505
# Adding data for ABC: 39 out of 505
# Adding data for AME: 40 out of 505
# Adding data for AMGN: 41 out of 505
# Adding data for APH: 42 out of 505
# Adding data for APC: 43 out of 505
# Adding data for ADI: 44 out of 505
# Adding data for ANDV: 45 out of 505
# Adding data for ANSS: 46 out of 505
# Adding data for ANTM: 47 out of 505
# Adding data for AON: 48 out of 505
# Adding data for AOS: 49 out of 505
# Adding data for APA: 50 out of 505
# Adding data for AIV: 51 out of 505
# Adding data for AAPL: 52 out of 505
# Adding data for AMAT: 53 out of 505
# Adding data for ADM: 54 out of 505
# Adding data for ARNC: 55 out of 505
# Adding data for AJG: 56 out of 505
# Adding data for AIZ: 57 out of 505
# Adding data for T: 58 out of 505
# Adding data for ADSK: 59 out of 505
# Adding data for ADP: 60 out of 505
# Adding data for AZO: 61 out of 505
# Adding data for AVB: 62 out of 505
# Adding data for AVY: 63 out of 505
# Adding data for BHGE: 64 out of 505
# Error processing BHGE
# Adding data for BLL: 65 out of 505
# Adding data for BAC: 66 out of 505
# Adding data for BK: 67 out of 505
# Adding data for BCR: 68 out of 505
# Adding data for BAX: 69 out of 505
# Adding data for BBT: 70 out of 505
# Adding data for BDX: 71 out of 505
# Adding data for BRK.B: 72 out of 505
# Could not download Yahoo data: Unable to read URL: https://query1.finance.yahoo.com/v7/finance/download/BRK%2EB?crumb=godXilgRnpd&interval=1d&period2=1506322799&events=history&period1=1262332800
# Adding data for BBY: 73 out of 505
# Adding data for BIIB: 74 out of 505
# Adding data for BLK: 75 out of 505
# Adding data for HRB: 76 out of 505
# Adding data for BA: 77 out of 505
# Adding data for BWA: 78 out of 505
# Adding data for BXP: 79 out of 505
# Adding data for BSX: 80 out of 505
# Adding data for BHF: 81 out of 505
# Error processing BHF
# Adding data for BMY: 82 out of 505
# Adding data for AVGO: 83 out of 505
# Adding data for BF.B: 84 out of 505
# Could not download Yahoo data: Unable to read URL: https://query1.finance.yahoo.com/v7/finance/download/BF%2EB?crumb=Bo8s6K8DMYY&interval=1d&period2=1506322799&events=history&period1=1262332800
# Adding data for CHRW: 85 out of 505
# Adding data for CA: 86 out of 505
# Adding data for COG: 87 out of 505
# Adding data for CDNS: 88 out of 505
# Error processing CDNS
# Adding data for CPB: 89 out of 505
# Adding data for COF: 90 out of 505
# Adding data for CAH: 91 out of 505
# Adding data for CBOE: 92 out of 505
# Adding data for KMX: 93 out of 505
# Adding data for CCL: 94 out of 505
# Adding data for CAT: 95 out of 505
# Adding data for CBG: 96 out of 505
# Adding data for CBS: 97 out of 505
# Adding data for CELG: 98 out of 505
# Adding data for CNC: 99 out of 505
# Adding data for CNP: 100 out of 505
# Adding data for CTL: 101 out of 505
# Adding data for CERN: 102 out of 505
# Adding data for CF: 103 out of 505
# Adding data for SCHW: 104 out of 505
# Adding data for CHTR: 105 out of 505
# Adding data for CHK: 106 out of 505
# Adding data for CVX: 107 out of 505
# Adding data for CMG: 108 out of 505
# Adding data for CB: 109 out of 505
# Adding data for CHD: 110 out of 505
# Adding data for CI: 111 out of 505
# Adding data for XEC: 112 out of 505
# Adding data for CINF: 113 out of 505
# Adding data for CTAS: 114 out of 505
# Adding data for CSCO: 115 out of 505
# Adding data for C: 116 out of 505
# Adding data for CFG: 117 out of 505
# Adding data for CTXS: 118 out of 505
# Adding data for CLX: 119 out of 505
# Adding data for CME: 120 out of 505
# Adding data for CMS: 121 out of 505
# Adding data for COH: 122 out of 505
# Adding data for KO: 123 out of 505
# Adding data for CTSH: 124 out of 505
# Adding data for CL: 125 out of 505
# Adding data for CMCSA: 126 out of 505
# Adding data for CMA: 127 out of 505
# Adding data for CAG: 128 out of 505
# Adding data for CXO: 129 out of 505
# Adding data for COP: 130 out of 505
# Adding data for ED: 131 out of 505
# Adding data for STZ: 132 out of 505
# Adding data for COO: 133 out of 505
# Adding data for GLW: 134 out of 505
# Adding data for COST: 135 out of 505
# Adding data for COTY: 136 out of 505
# Adding data for CCI: 137 out of 505
# Adding data for CSRA: 138 out of 505
# Adding data for CSX: 139 out of 505
# Adding data for CMI: 140 out of 505
# Adding data for CVS: 141 out of 505
# Adding data for DHI: 142 out of 505
# Adding data for DHR: 143 out of 505
# Adding data for DRI: 144 out of 505
# Adding data for DVA: 145 out of 505
# Adding data for DE: 146 out of 505
# Adding data for DLPH: 147 out of 505
# Adding data for DAL: 148 out of 505
# Adding data for XRAY: 149 out of 505
# Adding data for DVN: 150 out of 505
# Adding data for DLR: 151 out of 505
# Adding data for DFS: 152 out of 505
# Adding data for DISCA: 153 out of 505
# Adding data for DISCK: 154 out of 505
# Adding data for DISH: 155 out of 505
# Adding data for DG: 156 out of 505
# Adding data for DLTR: 157 out of 505
# Adding data for D: 158 out of 505
# Adding data for DOV: 159 out of 505
# Adding data for DWDP: 160 out of 505
# Error processing DWDP
# Adding data for DPS: 161 out of 505
# Adding data for DTE: 162 out of 505
# Adding data for DRE: 163 out of 505
# Adding data for DUK: 164 out of 505
# Adding data for DXC: 165 out of 505
# Adding data for ETFC: 166 out of 505
# Adding data for EMN: 167 out of 505
# Adding data for ETN: 168 out of 505
# Adding data for EBAY: 169 out of 505
# Adding data for ECL: 170 out of 505
# Adding data for EIX: 171 out of 505
# Adding data for EW: 172 out of 505
# Adding data for EA: 173 out of 505
# Adding data for EMR: 174 out of 505
# Adding data for ETR: 175 out of 505
# Adding data for EVHC: 176 out of 505
# Adding data for EOG: 177 out of 505
# Adding data for EQT: 178 out of 505
# Adding data for EFX: 179 out of 505
# Adding data for EQIX: 180 out of 505
# Adding data for EQR: 181 out of 505
# Adding data for ESS: 182 out of 505
# Adding data for EL: 183 out of 505
# Adding data for ES: 184 out of 505
# Adding data for RE: 185 out of 505
# Error processing RE
# Adding data for EXC: 186 out of 505
# Adding data for EXPE: 187 out of 505
# Adding data for EXPD: 188 out of 505
# Adding data for ESRX: 189 out of 505
# Adding data for EXR: 190 out of 505
# Adding data for XOM: 191 out of 505
# Adding data for FFIV: 192 out of 505
# Adding data for FB: 193 out of 505
# Adding data for FAST: 194 out of 505
# Adding data for FRT: 195 out of 505
# Adding data for FDX: 196 out of 505
# Adding data for FIS: 197 out of 505
# Adding data for FITB: 198 out of 505
# Adding data for FE: 199 out of 505
# Adding data for FISV: 200 out of 505
# Adding data for FLIR: 201 out of 505
# Adding data for FLS: 202 out of 505
# Adding data for FLR: 203 out of 505
# Adding data for FMC: 204 out of 505
# Adding data for FL: 205 out of 505
# Adding data for F: 206 out of 505
# Adding data for FTV: 207 out of 505
# Adding data for FBHS: 208 out of 505
# Adding data for BEN: 209 out of 505
# Adding data for FCX: 210 out of 505
# Adding data for GPS: 211 out of 505
# Adding data for GRMN: 212 out of 505
# Adding data for IT: 213 out of 505
# Adding data for GD: 214 out of 505
# Adding data for GE: 215 out of 505
# Adding data for GGP: 216 out of 505
# Adding data for GIS: 217 out of 505
# Adding data for GM: 218 out of 505
# Adding data for GPC: 219 out of 505
# Adding data for GILD: 220 out of 505
# Adding data for GPN: 221 out of 505
# Adding data for GS: 222 out of 505
# Adding data for GT: 223 out of 505
# Adding data for GWW: 224 out of 505
# Adding data for HAL: 225 out of 505
# Adding data for HBI: 226 out of 505
# Adding data for HOG: 227 out of 505
# Adding data for HRS: 228 out of 505
# Adding data for HIG: 229 out of 505
# Adding data for HAS: 230 out of 505
# Adding data for HCA: 231 out of 505
# Adding data for HCP: 232 out of 505
# Adding data for HP: 233 out of 505
# Adding data for HSIC: 234 out of 505
# Adding data for HSY: 235 out of 505
# Adding data for HES: 236 out of 505
# Adding data for HPE: 237 out of 505
# Adding data for HLT: 238 out of 505
# Error processing HLT
# Adding data for HOLX: 239 out of 505
# Adding data for HD: 240 out of 505
# Adding data for HON: 241 out of 505
# Adding data for HRL: 242 out of 505
# Adding data for HST: 243 out of 505
# Adding data for HPQ: 244 out of 505
# Adding data for HUM: 245 out of 505
# Adding data for HBAN: 246 out of 505
# Adding data for IDXX: 247 out of 505
# Adding data for INFO: 248 out of 505
# Adding data for ITW: 249 out of 505
# Adding data for ILMN: 250 out of 505
# Adding data for IR: 251 out of 505
# Adding data for INTC: 252 out of 505
# Adding data for ICE: 253 out of 505
# Adding data for IBM: 254 out of 505
# Adding data for INCY: 255 out of 505
# Adding data for IP: 256 out of 505
# Adding data for IPG: 257 out of 505
# Adding data for IFF: 258 out of 505
# Adding data for INTU: 259 out of 505
# Adding data for ISRG: 260 out of 505
# Adding data for IVZ: 261 out of 505
# Adding data for IRM: 262 out of 505
# Adding data for JEC: 263 out of 505
# Adding data for JBHT: 264 out of 505
# Adding data for SJM: 265 out of 505
# Adding data for JNJ: 266 out of 505
# Adding data for JCI: 267 out of 505
# Adding data for JPM: 268 out of 505
# Adding data for JNPR: 269 out of 505
# Adding data for KSU: 270 out of 505
# Adding data for K: 271 out of 505
# Adding data for KEY: 272 out of 505
# Adding data for KMB: 273 out of 505
# Adding data for KIM: 274 out of 505
# Adding data for KMI: 275 out of 505
# Adding data for KLAC: 276 out of 505
# Adding data for KSS: 277 out of 505
# Adding data for KHC: 278 out of 505
# Adding data for KR: 279 out of 505
# Adding data for LB: 280 out of 505
# Adding data for LLL: 281 out of 505
# Adding data for LH: 282 out of 505
# Adding data for LRCX: 283 out of 505
# Adding data for LEG: 284 out of 505
# Adding data for LEN: 285 out of 505
# Adding data for LVLT: 286 out of 505
# Adding data for LUK: 287 out of 505
# Adding data for LLY: 288 out of 505
# Adding data for LNC: 289 out of 505
# Adding data for LKQ: 290 out of 505
# Adding data for LMT: 291 out of 505
# Adding data for L: 292 out of 505
# Adding data for LOW: 293 out of 505
# Adding data for LYB: 294 out of 505
# Adding data for MTB: 295 out of 505
# Adding data for MAC: 296 out of 505
# Adding data for M: 297 out of 505
# Adding data for MRO: 298 out of 505
# Adding data for MPC: 299 out of 505
# Adding data for MAR: 300 out of 505
# Adding data for MMC: 301 out of 505
# Adding data for MLM: 302 out of 505
# Adding data for MAS: 303 out of 505
# Adding data for MA: 304 out of 505
# Adding data for MAT: 305 out of 505
# Adding data for MKC: 306 out of 505
# Adding data for MCD: 307 out of 505
# Adding data for MCK: 308 out of 505
# Adding data for MDT: 309 out of 505
# Adding data for MRK: 310 out of 505
# Adding data for MET: 311 out of 505
# Adding data for MTD: 312 out of 505
# Adding data for MGM: 313 out of 505
# Adding data for KORS: 314 out of 505
# Adding data for MCHP: 315 out of 505
# Adding data for MU: 316 out of 505
# Adding data for MSFT: 317 out of 505
# Adding data for MAA: 318 out of 505
# Adding data for MHK: 319 out of 505
# Adding data for TAP: 320 out of 505
# Adding data for MDLZ: 321 out of 505
# Adding data for MON: 322 out of 505
# Adding data for MNST: 323 out of 505
# Adding data for MCO: 324 out of 505
# Adding data for MS: 325 out of 505
# Adding data for MOS: 326 out of 505
# Adding data for MSI: 327 out of 505
# Adding data for MYL: 328 out of 505
# Adding data for NDAQ: 329 out of 505
# Adding data for NOV: 330 out of 505
# Adding data for NAVI: 331 out of 505
# Adding data for NTAP: 332 out of 505
# Adding data for NFLX: 333 out of 505
# Adding data for NWL: 334 out of 505
# Adding data for NFX: 335 out of 505
# Adding data for NEM: 336 out of 505
# Adding data for NWSA: 337 out of 505
# Adding data for NWS: 338 out of 505
# Adding data for NEE: 339 out of 505
# Adding data for NLSN: 340 out of 505
# Adding data for NKE: 341 out of 505
# Adding data for NI: 342 out of 505
# Adding data for NBL: 343 out of 505
# Adding data for JWN: 344 out of 505
# Adding data for NSC: 345 out of 505
# Adding data for NTRS: 346 out of 505
# Adding data for NOC: 347 out of 505
# Adding data for NRG: 348 out of 505
# Adding data for NUE: 349 out of 505
# Adding data for NVDA: 350 out of 505
# Adding data for ORLY: 351 out of 505
# Adding data for OXY: 352 out of 505
# Adding data for OMC: 353 out of 505
# Adding data for OKE: 354 out of 505
# Adding data for ORCL: 355 out of 505
# Adding data for PCAR: 356 out of 505
# Adding data for PKG: 357 out of 505
# Error processing PKG
# Adding data for PH: 358 out of 505
# Adding data for PDCO: 359 out of 505
# Adding data for PAYX: 360 out of 505
# Adding data for PYPL: 361 out of 505
# Adding data for PNR: 362 out of 505
# Adding data for PBCT: 363 out of 505
# Adding data for PEP: 364 out of 505
# Adding data for PKI: 365 out of 505
# Adding data for PRGO: 366 out of 505
# Adding data for PFE: 367 out of 505
# Adding data for PCG: 368 out of 505
# Adding data for PM: 369 out of 505
# Adding data for PSX: 370 out of 505
# Adding data for PNW: 371 out of 505
# Adding data for PXD: 372 out of 505
# Adding data for PNC: 373 out of 505
# Adding data for RL: 374 out of 505
# Adding data for PPG: 375 out of 505
# Adding data for PPL: 376 out of 505
# Adding data for PX: 377 out of 505
# Adding data for PCLN: 378 out of 505
# Adding data for PFG: 379 out of 505
# Error processing PFG
# Adding data for PG: 380 out of 505
# Adding data for PGR: 381 out of 505
# Adding data for PLD: 382 out of 505
# Adding data for PRU: 383 out of 505
# Adding data for PEG: 384 out of 505
# Adding data for PSA: 385 out of 505
# Adding data for PHM: 386 out of 505
# Adding data for PVH: 387 out of 505
# Adding data for QRVO: 388 out of 505
# Adding data for PWR: 389 out of 505
# Adding data for QCOM: 390 out of 505
# Adding data for DGX: 391 out of 505
# Adding data for Q: 392 out of 505
# Adding data for RRC: 393 out of 505
# Adding data for RJF: 394 out of 505
# Error processing RJF
# Adding data for RTN: 395 out of 505
# Adding data for O: 396 out of 505
# Adding data for RHT: 397 out of 505
# Adding data for REG: 398 out of 505
# Error processing REG
# Adding data for REGN: 399 out of 505
# Adding data for RF: 400 out of 505
# Adding data for RSG: 401 out of 505
# Adding data for RMD: 402 out of 505
# Adding data for RHI: 403 out of 505
# Adding data for ROK: 404 out of 505
# Adding data for COL: 405 out of 505
# Adding data for ROP: 406 out of 505
# Adding data for ROST: 407 out of 505
# Adding data for RCL: 408 out of 505
# Adding data for CRM: 409 out of 505
# Adding data for SBAC: 410 out of 505
# Adding data for SCG: 411 out of 505
# Adding data for SLB: 412 out of 505
# Adding data for SNI: 413 out of 505
# Adding data for STX: 414 out of 505
# Adding data for SEE: 415 out of 505
# Adding data for SRE: 416 out of 505
# Adding data for SHW: 417 out of 505
# Adding data for SIG: 418 out of 505
# Adding data for SPG: 419 out of 505
# Adding data for SWKS: 420 out of 505
# Adding data for SLG: 421 out of 505
# Adding data for SNA: 422 out of 505
# Error processing SNA
# Adding data for SO: 423 out of 505
# Adding data for LUV: 424 out of 505
# Adding data for SPGI: 425 out of 505
# Adding data for SWK: 426 out of 505
# Adding data for SBUX: 427 out of 505
# Adding data for STT: 428 out of 505
# Adding data for SRCL: 429 out of 505
# Adding data for SYK: 430 out of 505
# Adding data for STI: 431 out of 505
# Error processing STI
# Adding data for SYMC: 432 out of 505
# Adding data for SYF: 433 out of 505
# Adding data for SNPS: 434 out of 505
# Adding data for SYY: 435 out of 505
# Adding data for TROW: 436 out of 505
# Adding data for TGT: 437 out of 505
# Adding data for TEL: 438 out of 505
# Adding data for FTI: 439 out of 505
# Adding data for TXN: 440 out of 505
# Adding data for TXT: 441 out of 505
# Adding data for TMO: 442 out of 505
# Adding data for TIF: 443 out of 505
# Adding data for TWX: 444 out of 505
# Adding data for TJX: 445 out of 505
# Adding data for TMK: 446 out of 505
# Adding data for TSS: 447 out of 505
# Adding data for TSCO: 448 out of 505
# Adding data for TDG: 449 out of 505
# Adding data for TRV: 450 out of 505
# Adding data for TRIP: 451 out of 505
# Adding data for FOXA: 452 out of 505
# Adding data for FOX: 453 out of 505
# Adding data for TSN: 454 out of 505
# Adding data for UDR: 455 out of 505
# Adding data for ULTA: 456 out of 505
# Adding data for USB: 457 out of 505
# Adding data for UA: 458 out of 505
# Error processing UA
# Adding data for UAA: 459 out of 505
# Adding data for UNP: 460 out of 505
# Adding data for UAL: 461 out of 505
# Adding data for UNH: 462 out of 505
# Adding data for UPS: 463 out of 505
# Adding data for URI: 464 out of 505
# Adding data for UTX: 465 out of 505
# Adding data for UHS: 466 out of 505
# Adding data for UNM: 467 out of 505
# Adding data for VFC: 468 out of 505
# Adding data for VLO: 469 out of 505
# Adding data for VAR: 470 out of 505
# Adding data for VTR: 471 out of 505
# Adding data for VRSN: 472 out of 505
# Adding data for VRSK: 473 out of 505
# Adding data for VZ: 474 out of 505
# Adding data for VRTX: 475 out of 505
# Adding data for VIAB: 476 out of 505
# Adding data for V: 477 out of 505
# Adding data for VNO: 478 out of 505
# Adding data for VMC: 479 out of 505
# Adding data for WMT: 480 out of 505
# Adding data for WBA: 481 out of 505
# Adding data for DIS: 482 out of 505
# Adding data for WM: 483 out of 505
# Adding data for WAT: 484 out of 505
# Adding data for WEC: 485 out of 505
# Adding data for WFC: 486 out of 505
# Adding data for HCN: 487 out of 505
# Adding data for WDC: 488 out of 505
# Adding data for WU: 489 out of 505
# Adding data for WRK: 490 out of 505
# Adding data for WY: 491 out of 505
# Adding data for WHR: 492 out of 505
# Adding data for WMB: 493 out of 505
# Adding data for WLTW: 494 out of 505
# Adding data for WYN: 495 out of 505
# Adding data for WYNN: 496 out of 505
# Adding data for XEL: 497 out of 505
# Adding data for XRX: 498 out of 505
# Adding data for XLNX: 499 out of 505
# Adding data for XL: 500 out of 505
# Adding data for XYL: 501 out of 505
# Adding data for YUM: 502 out of 505
# Adding data for ZBH: 503 out of 505
# Adding data for ZION: 504 out of 505
# Error processing ZION
# Adding data for ZTS: 505 out of 505
# Successfully added data.

# %%
errored = ['BHGE', 'BHF', 'CDNS', 'DWDP', 'RE', 'HLT', 'PKG', 'PFG', 'RJF', 'REG', 'SNA', 'STI', 'UA', 'ZION']

# %%
# Read Data
con = mdb.connect(
    host=db_host, user=db_user, passwd=db_pass, db=db_name
)

sql = """SELECT dp.price_date, dp.adj_close_price
FROM symbol AS sym
INNER JOIN daily_price AS dp
ON dp.symbol_id = sym.id
WHERE sym.ticker = 'GOOG'
ORDER BY dp.price_date ASC;"""

goog = pd.read_sql_query(sql, con=con, index_col="price_date")
print(goog.tail())
# Out:
#             adj_close_price
# price_date
# 2017-09-18        1306900.0
# 2017-09-19         936700.0
# 2017-09-20        1669800.0
# 2017-09-21        1290600.0
# 2017-09-22        1040400.0
